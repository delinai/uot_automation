# %%
def mean(x):
    mean = sum(x)/len(x)
    return mean

# %%
list1 = [1,2,4,8,7]
mean(list1)
# Out:
# 4.4

# %%
import numpy as np

# %%
np.mean(list1)
# Out:
# 4.4

# %%
pip install numpy
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from numpy import median

# %%
dummy_dataframe = pd.DataFrame({'col1':[1,2,3,4], 'col2':[8,7,9,6]})

# %%
dummy_dataframe
# Out:
#    col1  col2
# 0     1     8
# 1     2     7
# 2     3     9
# 3     4     6

# %%
dummy_series = pd.Series([1,7,8,9,6])

# %%
dummy_series
# Out:
# 0    1
# 1    7
# 2    8
# 3    9
# 4    6
# dtype: int64

# %%
type(dummy_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dummy_series)
# Out:
# pandas.core.series.Series

# %%
type(dummy_dataframe['col1'])
# Out:
# pandas.core.series.Series

# %%
dummy_dataframe
# Out:
#    col1  col2
# 0     1     8
# 1     2     7
# 2     3     9
# 3     4     6

# %%
new_list = dummy_dataframe['col1'].to_list()

# %%
new_list.extend([5,4,7,8])

# %%
updated_dataframe = pd.concat([pd.Series(new_list),dummy_dataframe['col2']], axis=1)

# %%
updated_dataframe.columns = ['col1','col2']

# %%
updated_dataframe
# Out:
#    col1  col2
# 0     1   8.0
# 1     2   7.0
# 2     3   9.0
# 3     4   6.0
# 4     5   NaN
# 5     4   NaN
# 6     7   NaN
# 7     8   NaN

# %%
dummy_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
# dtypes: int64(2)
# memory usage: 192.0 bytes

# %%
updated_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    8 non-null      int64
#  1   col2    4 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 256.0 bytes

# %%
dummy_dataframe.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
dummy_dataframe.columns
# Out:
# Index(['col1', 'col2'], dtype='object')

# %%
dummy_dataframe.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1), Index(['col1', 'col2'], dtype='object')]

# %%
dummy_dataframe.head(2)
# Out:
#    col1  col2
# 0     1     8
# 1     2     7

# %%
dummy_dataframe.tail(2)
# Out:
#    col1  col2
# 2     3     9
# 3     4     6

# %%
dummy_dataframe.describe()
# Out:
#            col1      col2
# count  4.000000  4.000000
# mean   2.500000  7.500000
# std    1.290994  1.290994
# min    1.000000  6.000000
# 25%    1.750000  6.750000
# 50%    2.500000  7.500000
# 75%    3.250000  8.250000
# max    4.000000  9.000000

# %%
# isolating a specific column
dummy_dataframe.col1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: col1, dtype: int64

# %%
dummy_dataframe['col1']
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: col1, dtype: int64

# %%
dict1 = {'col1':[1,2,87], 'col2':[7,6,75,4]}

# %%
dict1['col1']
# Out:
# [1, 2, 87]

# %%
list1[1]
# Out:
# 2

# %%
dummy_dataframe.iloc[2].loc['col1']
# Out:
# 3

# %%
dummy_dataframe.loc[0].iloc[1]
# Out:
# 8

# %%
dummy_dataframe
# Out:
#    col1  col2
# 0     1     8
# 1     2     7
# 2     3     9
# 3     4     6

# %%
dummy_dataframe.iloc[0]#.loc['col1']
# Out:
# col1    1
# col2    8
# Name: 0, dtype: int64

# %%
dummy_dataframe.index = ['val1','val2','val3','val4']

# %%
dummy_dataframe
# Out:
#       col1  col2
# val1     1     8
# val2     2     7
# val3     3     9
# val4     4     6

# %%
dummy_dataframe.loc['val1']
# Out:
# col1    1
# col2    8
# Name: val1, dtype: int64

# %%
dummy_dataframe.iloc[0].iloc[1]
# Out:
# 8

# %%
dummy_dataframe
# Out:
#       col1  col2
# val1     1     8
# val2     2     7
# val3     3     9
# val4     4     6

# %%
dummy_dataframe.loc['val1','col1']
# Out:
# 1

# %%
dummy_dataframe.iloc[1,1]
# Out:
# 7

# %%
dummy_dataframe.iloc[0:2,1] # slicing a range of rows, and the column in position 1 (second position)
# Out:
# val1    8
# val2    7
# Name: col2, dtype: int64

# %%
dummy_dataframe
# Out:
#       col1  col2
# val1     1     8
# val2     2     7
# val3     3     9
# val4     4     6

# %%
dummy_dataframe.loc[['val1','val3'],['col1','col2']] # slicing select rows, and select columns - we need to pass a list of conditions thus 2 sets of brackets
# Out:
#       col1  col2
# val1     1     8
# val3     3     9

# %%
dummy_dataframe.iloc[[0,2],[0,1]] # same as above, except slicing based on position
# Out:
#       col1  col2
# val1     1     8
# val3     3     9

# %%
orders = pd.read_csv('https://raw.githubusercontent.com/delinai/uot_automation/main/customer_orders.csv')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_date       14 non-null     object
#  1   customer_id      14 non-null     int64
#  2   name             14 non-null     object
#  3   email            12 non-null     object
#  4   product_id       14 non-null     int64
#  5   brand            14 non-null     object
#  6   next_action      0 non-null      float64
#  7   delivery_date    0 non-null      float64
#  8   delivery_route   0 non-null      float64
#  9   account_manager  0 non-null      float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 1.2+ KB

# %%
orders.head()
# Out:
#    order_date  customer_id           name             email  product_id  \
# 0  2022-01-01         1001     John Adams    john@email.com          12
# 1  2022-01-02         1002    Jorden Haas  jorden@email.com          13
# 2  2022-01-03         1001     John Adams    john@email.com          13
# 3  2022-01-04         1002    Jorden Haas  jorden@email.com          14
# 4  2022-01-05         1003  Pierce Glover  pierce@email.com          12
#
#     brand  next_action  delivery_date  delivery_route  account_manager
# 0     ABC          NaN            NaN             NaN              NaN
# 1  Brand2          NaN            NaN             NaN              NaN
# 2  Brand2          NaN            NaN             NaN              NaN
# 3     ABC          NaN            NaN             NaN              NaN
# 4     ABC          NaN            NaN             NaN              NaN

# %%
orders.tail()
# Out:
#     order_date  customer_id            name             email  product_id  \
# 9   2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 11  2022-01-12         1004  Carly Copeland               NaN          15
# 12  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 13  2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand  next_action  delivery_date  delivery_route  account_manager
# 9      ABC          NaN            NaN             NaN              NaN
# 10  Brand2          NaN            NaN             NaN              NaN
# 11      DT          NaN            NaN             NaN              NaN
# 12     ABC          NaN            NaN             NaN              NaN
# 13      DT          NaN            NaN             NaN              NaN

# %%
orders[['order_date','name']] # Isolate specific columns
# Out:
#     order_date            name
# 0   2022-01-01      John Adams
# 1   2022-01-02     Jorden Haas
# 2   2022-01-03      John Adams
# 3   2022-01-04     Jorden Haas
# 4   2022-01-05   Pierce Glover
# 5   2022-01-06      John Adams
# 6   2022-01-07     Jorden Haas
# 7   2022-01-08   Pierce Glover
# 8   2022-01-09  Carly Copeland
# 9   2022-01-10     Jorden Haas
# 10  2022-01-11   Pierce Glover
# 11  2022-01-12  Carly Copeland
# 12  2022-01-13   Pierce Glover
# 13  2022-01-14  Carly Copeland

# %%
orders.iloc[[10,13]]
# Out:
#     order_date  customer_id            name             email  product_id  \
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 13  2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand  next_action  delivery_date  delivery_route  account_manager
# 10  Brand2          NaN            NaN             NaN              NaN
# 13      DT          NaN            NaN             NaN              NaN

# %%
orders.set_index('customer_id')
# Out:
#              order_date            name             email  product_id   brand  \
# customer_id
# 1001         2022-01-01      John Adams    john@email.com          12     ABC
# 1002         2022-01-02     Jorden Haas  jorden@email.com          13  Brand2
# 1001         2022-01-03      John Adams    john@email.com          13  Brand2
# 1002         2022-01-04     Jorden Haas  jorden@email.com          14     ABC
# 1003         2022-01-05   Pierce Glover  pierce@email.com          12     ABC
# 1001         2022-01-06      John Adams    john@email.com          14     ABC
# 1002         2022-01-07     Jorden Haas  jorden@email.com          14     ABC
# 1003         2022-01-08   Pierce Glover  pierce@email.com          13  Brand2
# 1004         2022-01-09  Carly Copeland   carly@email.com          12     ABC
# 1002         2022-01-10     Jorden Haas  jorden@email.com          12     ABC
# 1003         2022-01-11   Pierce Glover  pierce@email.com          13  Brand2
# ...

# %%
list1.append(3) # this is an inplace change

# %%
list1.sort() # inplace sort

# %%
list1
# Out:
# [1, 2, 3, 4, 7, 8]

# %%
sorted(list1, reverse=True) # this function is NOT an inplace change
# Out:
# [8, 7, 4, 3, 2, 1]

# %%
list1
# Out:
# [1, 2, 3, 4, 7, 8]

# %%
cx_1001 = orders.set_index('customer_id').loc[1001]

# %%
orders
# Out:
#     order_date  customer_id            name             email  product_id  \
# 0   2022-01-01         1001      John Adams    john@email.com          12
# 1   2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 2   2022-01-03         1001      John Adams    john@email.com          13
# 3   2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 4   2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 5   2022-01-06         1001      John Adams    john@email.com          14
# 6   2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 7   2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 8   2022-01-09         1004  Carly Copeland   carly@email.com          12
# 9   2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 10  2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 11  2022-01-12         1004  Carly Copeland               NaN          15
# ...

# %%
cx_1001
# Out:
#              order_date        name           email  product_id   brand  \
# customer_id
# 1001         2022-01-01  John Adams  john@email.com          12     ABC
# 1001         2022-01-03  John Adams  john@email.com          13  Brand2
# 1001         2022-01-06  John Adams  john@email.com          14     ABC
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# 1001                 NaN            NaN             NaN              NaN
# 1001                 NaN            NaN             NaN              NaN
# 1001                 NaN            NaN             NaN              NaN

# %%
orders.set_index('customer_id', inplace=True) # inplace=True makes the change permanent

# %%
orders.loc[1002]
# Out:
#              order_date         name             email  product_id   brand  \
# customer_id
# 1002         2022-01-02  Jorden Haas  jorden@email.com          13  Brand2
# 1002         2022-01-04  Jorden Haas  jorden@email.com          14     ABC
# 1002         2022-01-07  Jorden Haas  jorden@email.com          14     ABC
# 1002         2022-01-10  Jorden Haas  jorden@email.com          12     ABC
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# 1002                 NaN            NaN             NaN              NaN
# 1002                 NaN            NaN             NaN              NaN
# 1002                 NaN            NaN             NaN              NaN
# 1002                 NaN            NaN             NaN              NaN

# %%
orders.iloc[[4,9]]
# Out:
#              order_date           name             email  product_id brand  \
# customer_id
# 1003         2022-01-05  Pierce Glover  pierce@email.com          12   ABC
# 1002         2022-01-10    Jorden Haas  jorden@email.com          12   ABC
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# 1003                 NaN            NaN             NaN              NaN
# 1002                 NaN            NaN             NaN              NaN

# %%
orders.reset_index().set_index('name') # the set_index() function drops the old index, so to avoid losing valuable data, reset_index() first
# Out:
#                 customer_id  order_date             email  product_id   brand  \
# name
# John Adams             1001  2022-01-01    john@email.com          12     ABC
# Jorden Haas            1002  2022-01-02  jorden@email.com          13  Brand2
# John Adams             1001  2022-01-03    john@email.com          13  Brand2
# Jorden Haas            1002  2022-01-04  jorden@email.com          14     ABC
# Pierce Glover          1003  2022-01-05  pierce@email.com          12     ABC
# John Adams             1001  2022-01-06    john@email.com          14     ABC
# Jorden Haas            1002  2022-01-07  jorden@email.com          14     ABC
# Pierce Glover          1003  2022-01-08  pierce@email.com          13  Brand2
# Carly Copeland         1004  2022-01-09   carly@email.com          12     ABC
# Jorden Haas            1002  2022-01-10  jorden@email.com          12     ABC
# Pierce Glover          1003  2022-01-11  pierce@email.com          13  Brand2
# ...

# %%
orders.sort_index() # by default, this sorts smallest to largest
# Out:
#              order_date            name             email  product_id   brand  \
# customer_id
# 1001         2022-01-01      John Adams    john@email.com          12     ABC
# 1001         2022-01-03      John Adams    john@email.com          13  Brand2
# 1001         2022-01-06      John Adams    john@email.com          14     ABC
# 1002         2022-01-02     Jorden Haas  jorden@email.com          13  Brand2
# 1002         2022-01-04     Jorden Haas  jorden@email.com          14     ABC
# 1002         2022-01-07     Jorden Haas  jorden@email.com          14     ABC
# 1002         2022-01-10     Jorden Haas  jorden@email.com          12     ABC
# 1003         2022-01-05   Pierce Glover  pierce@email.com          12     ABC
# 1003         2022-01-08   Pierce Glover  pierce@email.com          13  Brand2
# 1003         2022-01-11   Pierce Glover  pierce@email.com          13  Brand2
# 1003         2022-01-13   Pierce Glover  pierce@email.com          12     ABC
# ...

# %%
orders.sort_index(ascending=False)
# Out:
#              order_date            name             email  product_id   brand  \
# customer_id
# 1004         2022-01-09  Carly Copeland   carly@email.com          12     ABC
# 1004         2022-01-12  Carly Copeland               NaN          15      DT
# 1004         2022-01-14  Carly Copeland               NaN          15      DT
# 1003         2022-01-05   Pierce Glover  pierce@email.com          12     ABC
# 1003         2022-01-08   Pierce Glover  pierce@email.com          13  Brand2
# 1003         2022-01-11   Pierce Glover  pierce@email.com          13  Brand2
# 1003         2022-01-13   Pierce Glover  pierce@email.com          12     ABC
# 1002         2022-01-02     Jorden Haas  jorden@email.com          13  Brand2
# 1002         2022-01-04     Jorden Haas  jorden@email.com          14     ABC
# 1002         2022-01-07     Jorden Haas  jorden@email.com          14     ABC
# 1002         2022-01-10     Jorden Haas  jorden@email.com          12     ABC
# ...

# %%
orders.reset_index().set_index('order_date').sort_index(ascending=False).head(5) # Isolate the last 5 orders
# Out:
#             customer_id            name             email  product_id   brand  \
# order_date
# 2022-01-14         1004  Carly Copeland               NaN          15      DT
# 2022-01-13         1003   Pierce Glover  pierce@email.com          12     ABC
# 2022-01-12         1004  Carly Copeland               NaN          15      DT
# 2022-01-11         1003   Pierce Glover  pierce@email.com          13  Brand2
# 2022-01-10         1002     Jorden Haas  jorden@email.com          12     ABC
#
#             next_action  delivery_date  delivery_route  account_manager
# order_date
# 2022-01-14          NaN            NaN             NaN              NaN
# 2022-01-13          NaN            NaN             NaN              NaN
# 2022-01-12          NaN            NaN             NaN              NaN
# 2022-01-11          NaN            NaN             NaN              NaN
# 2022-01-10          NaN            NaN             NaN              NaN

# %%
list_dates = ['1-1-2022','1-2-2022','1-14-2022']

# %%
sorted(list_dates)
# Out:
# ['1-1-2022', '1-14-2022', '1-2-2022']

# %%
#orders['order_date'] = orders['order_date'].astype('datetime64')

# %%
#orders.info()

# %%
#orders['delivery_date'] = orders['delivery_date'].astype('datetime64[ns]')

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
orders.reset_index().set_index('order_date').sort_index(ascending=False)
# Out:
#             customer_id            name             email  product_id   brand  \
# order_date
# 2022-01-14         1004  Carly Copeland               NaN          15      DT
# 2022-01-13         1003   Pierce Glover  pierce@email.com          12     ABC
# 2022-01-12         1004  Carly Copeland               NaN          15      DT
# 2022-01-11         1003   Pierce Glover  pierce@email.com          13  Brand2
# 2022-01-10         1002     Jorden Haas  jorden@email.com          12     ABC
# 2022-01-09         1004  Carly Copeland   carly@email.com          12     ABC
# 2022-01-08         1003   Pierce Glover  pierce@email.com          13  Brand2
# 2022-01-07         1002     Jorden Haas  jorden@email.com          14     ABC
# 2022-01-06         1001      John Adams    john@email.com          14     ABC
# 2022-01-05         1003   Pierce Glover  pierce@email.com          12     ABC
# 2022-01-04         1002     Jorden Haas  jorden@email.com          14     ABC
# ...

# %%
orders[orders['brand'] == 'ABC']
# Out:
#             order_date            name             email  product_id brand  \
# customer_id
# 1001        2022-01-01      John Adams    john@email.com          12   ABC
# 1002        2022-01-04     Jorden Haas  jorden@email.com          14   ABC
# 1003        2022-01-05   Pierce Glover  pierce@email.com          12   ABC
# 1001        2022-01-06      John Adams    john@email.com          14   ABC
# 1002        2022-01-07     Jorden Haas  jorden@email.com          14   ABC
# 1004        2022-01-09  Carly Copeland   carly@email.com          12   ABC
# 1002        2022-01-10     Jorden Haas  jorden@email.com          12   ABC
# 1003        2022-01-13   Pierce Glover  pierce@email.com          12   ABC
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# 1001                 NaN            NaN             NaN              NaN
# 1002                 NaN            NaN             NaN              NaN
# ...

# %%
orders['brand'] == 'ABC'
# Out:
# customer_id
# 1001     True
# 1002    False
# 1001    False
# 1002     True
# 1003     True
# 1001     True
# 1002     True
# 1003    False
# 1004     True
# 1002     True
# 1003    False
# 1004    False
# 1003     True
# 1004    False
# Name: brand, dtype: bool

# %%
orders[orders['product_id'] > 12]
# Out:
#             order_date            name             email  product_id   brand  \
# customer_id
# 1002        2022-01-02     Jorden Haas  jorden@email.com          13  Brand2
# 1001        2022-01-03      John Adams    john@email.com          13  Brand2
# 1002        2022-01-04     Jorden Haas  jorden@email.com          14     ABC
# 1001        2022-01-06      John Adams    john@email.com          14     ABC
# 1002        2022-01-07     Jorden Haas  jorden@email.com          14     ABC
# 1003        2022-01-08   Pierce Glover  pierce@email.com          13  Brand2
# 1003        2022-01-11   Pierce Glover  pierce@email.com          13  Brand2
# 1004        2022-01-12  Carly Copeland               NaN          15      DT
# 1004        2022-01-14  Carly Copeland               NaN          15      DT
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# 1002                 NaN            NaN             NaN              NaN
# ...

# %%
orders[(orders['brand'] == 'ABC') & (orders['order_date'] < '2022-01-8 00:00:00')]
# Out:
#             order_date           name             email  product_id brand  \
# customer_id
# 1001        2022-01-01     John Adams    john@email.com          12   ABC
# 1002        2022-01-04    Jorden Haas  jorden@email.com          14   ABC
# 1003        2022-01-05  Pierce Glover  pierce@email.com          12   ABC
# 1001        2022-01-06     John Adams    john@email.com          14   ABC
# 1002        2022-01-07    Jorden Haas  jorden@email.com          14   ABC
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# 1001                 NaN            NaN             NaN              NaN
# 1002                 NaN            NaN             NaN              NaN
# 1003                 NaN            NaN             NaN              NaN
# 1001                 NaN            NaN             NaN              NaN
# 1002                 NaN            NaN             NaN              NaN

# %%
orders['order_date'].iloc[0]
# Out:
# Timestamp('2022-01-01 00:00:00')

# %%
orders[orders['brand'].isin(['ABC','DT'])] # Use the isin() function for a list of conditions in the same column
# Out:
#             order_date            name             email  product_id brand  \
# customer_id
# 1001        2022-01-01      John Adams    john@email.com          12   ABC
# 1002        2022-01-04     Jorden Haas  jorden@email.com          14   ABC
# 1003        2022-01-05   Pierce Glover  pierce@email.com          12   ABC
# 1001        2022-01-06      John Adams    john@email.com          14   ABC
# 1002        2022-01-07     Jorden Haas  jorden@email.com          14   ABC
# 1004        2022-01-09  Carly Copeland   carly@email.com          12   ABC
# 1002        2022-01-10     Jorden Haas  jorden@email.com          12   ABC
# 1004        2022-01-12  Carly Copeland               NaN          15    DT
# 1003        2022-01-13   Pierce Glover  pierce@email.com          12   ABC
# 1004        2022-01-14  Carly Copeland               NaN          15    DT
#
#              next_action  delivery_date  delivery_route  account_manager
# customer_id
# ...

# %%
account_mgr = pd.read_csv('https://raw.githubusercontent.com/delinai/uot_automation/main/account_managers.csv')

# %%
account_mgr
# Out:
#     brand account_manager
# 0     ABC          Johnny
# 1  Brand2           Timmy
# 2      DT           Sammy

# %% [markdown]
# There are 2 ways to connect two dataframes, using join() or merge()

# %%
merged_data = pd.merge(left = orders, right = account_mgr, left_on = 'brand', right_on='brand')

# %%
merged_data.head()
# Out:
#   order_date           name             email  product_id brand  next_action  \
# 0 2022-01-01     John Adams    john@email.com          12   ABC          NaN
# 1 2022-01-04    Jorden Haas  jorden@email.com          14   ABC          NaN
# 2 2022-01-05  Pierce Glover  pierce@email.com          12   ABC          NaN
# 3 2022-01-06     John Adams    john@email.com          14   ABC          NaN
# 4 2022-01-07    Jorden Haas  jorden@email.com          14   ABC          NaN
#
#    delivery_date  delivery_route  account_manager_x account_manager_y
# 0            NaN             NaN                NaN            Johnny
# 1            NaN             NaN                NaN            Johnny
# 2            NaN             NaN                NaN            Johnny
# 3            NaN             NaN                NaN            Johnny
# 4            NaN             NaN                NaN            Johnny

# %%
account_mgr.set_index('brand',inplace=True)

# %%
joined_data = orders.reset_index().set_index('brand').join(account_mgr, rsuffix='_x').drop('account_manager',axis=1) #dropping original account_mgr column

# %%
joined_data_v2 = orders.reset_index().set_index('brand').drop('account_manager',axis=1).join(account_mgr)

# %%
joined_data.rename(columns={'account_manager_x':'account_manager'}, inplace=True)

# %%
joined_data
# Out:
#         customer_id order_date            name             email  product_id  \
# brand
# ABC            1001 2022-01-01      John Adams    john@email.com          12
# ABC            1002 2022-01-04     Jorden Haas  jorden@email.com          14
# ABC            1003 2022-01-05   Pierce Glover  pierce@email.com          12
# ABC            1001 2022-01-06      John Adams    john@email.com          14
# ABC            1002 2022-01-07     Jorden Haas  jorden@email.com          14
# ABC            1004 2022-01-09  Carly Copeland   carly@email.com          12
# ABC            1002 2022-01-10     Jorden Haas  jorden@email.com          12
# ABC            1003 2022-01-13   Pierce Glover  pierce@email.com          12
# Brand2         1002 2022-01-02     Jorden Haas  jorden@email.com          13
# Brand2         1001 2022-01-03      John Adams    john@email.com          13
# Brand2         1003 2022-01-08   Pierce Glover  pierce@email.com          13
# ...

# %%
joined_data_v2
# Out:
#         customer_id order_date            name             email  product_id  \
# brand
# ABC            1001 2022-01-01      John Adams    john@email.com          12
# ABC            1002 2022-01-04     Jorden Haas  jorden@email.com          14
# ABC            1003 2022-01-05   Pierce Glover  pierce@email.com          12
# ABC            1001 2022-01-06      John Adams    john@email.com          14
# ABC            1002 2022-01-07     Jorden Haas  jorden@email.com          14
# ABC            1004 2022-01-09  Carly Copeland   carly@email.com          12
# ABC            1002 2022-01-10     Jorden Haas  jorden@email.com          12
# ABC            1003 2022-01-13   Pierce Glover  pierce@email.com          12
# Brand2         1002 2022-01-02     Jorden Haas  jorden@email.com          13
# Brand2         1001 2022-01-03      John Adams    john@email.com          13
# Brand2         1003 2022-01-08   Pierce Glover  pierce@email.com          13
# ...
