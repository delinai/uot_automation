# %%
import pandas as pd

# %%
orders = pd.read_csv('https://raw.githubusercontent.com/delinai/uot_automation/main/customer_orders.csv')
am = pd.read_csv('https://raw.githubusercontent.com/delinai/uot_automation/main/account_managers.csv')

# %%
orders.head()
# Out:
#    order_date  customer_id           name             email  product_id  \
# 0  2022-01-01         1001     John Adams    john@email.com          12
# 1  2022-01-02         1002    Jorden Haas  jorden@email.com          13
# 2  2022-01-03         1001     John Adams    john@email.com          13
# 3  2022-01-04         1002    Jorden Haas  jorden@email.com          14
# 4  2022-01-05         1003  Pierce Glover  pierce@email.com          12
#
#     brand  next_action  delivery_date  delivery_route  account_manager
# 0     ABC          NaN            NaN             NaN              NaN
# 1  Brand2          NaN            NaN             NaN              NaN
# 2  Brand2          NaN            NaN             NaN              NaN
# 3     ABC          NaN            NaN             NaN              NaN
# 4     ABC          NaN            NaN             NaN              NaN

# %%
am.head()
# Out:
#     brand account_manager
# 0     ABC          Johnny
# 1  Brand2           Timmy
# 2      DT           Sammy

# %%
orders['order_date'] = pd.to_datetime(orders['order_date'])

# %%
updated_orders = pd.merge(left=orders, right=am, left_on='brand', right_on='brand')

# %%
updated_orders.drop('account_manager_x', axis=1, inplace=True)
updated_orders.rename(columns={'account_manager_y':'account_manager'}, inplace=True)

# %%
updated_orders
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 1  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 2  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 3  2022-01-06         1001      John Adams    john@email.com          14
# 4  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 5  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 6  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 7  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 8  2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 9  2022-01-03         1001      John Adams    john@email.com          13
# 10 2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 11 2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 12 2022-01-12         1004  Carly Copeland               NaN          15
# 13 2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand  next_action  delivery_date  delivery_route account_manager
# 0      ABC          NaN            NaN             NaN          Johnny
# 1      ABC          NaN            NaN             NaN          Johnny
# 2      ABC          NaN            NaN             NaN          Johnny
# 3      ABC          NaN            NaN             NaN          Johnny
# 4      ABC          NaN            NaN             NaN          Johnny
# 5      ABC          NaN            NaN             NaN          Johnny
# 6      ABC          NaN            NaN             NaN          Johnny
# 7      ABC          NaN            NaN             NaN          Johnny
# 8   Brand2          NaN            NaN             NaN           Timmy
# 9   Brand2          NaN            NaN             NaN           Timmy
# 10  Brand2          NaN            NaN             NaN           Timmy
# 11  Brand2          NaN            NaN             NaN           Timmy
# 12      DT          NaN            NaN             NaN           Sammy
# 13      DT          NaN            NaN             NaN           Sammy

# %%
action_dict = {12:'Follow-up with Cx', 14:'Follow-up with Cx', 13:'Ship Product', 15:'Ship Product'}

# %%
updated_orders['next_action'] = updated_orders['product_id'].map(action_dict)

# %%
updated_orders.head()
# Out:
#   order_date  customer_id           name             email  product_id brand  \
# 0 2022-01-01         1001     John Adams    john@email.com          12   ABC
# 1 2022-01-04         1002    Jorden Haas  jorden@email.com          14   ABC
# 2 2022-01-05         1003  Pierce Glover  pierce@email.com          12   ABC
# 3 2022-01-06         1001     John Adams    john@email.com          14   ABC
# 4 2022-01-07         1002    Jorden Haas  jorden@email.com          14   ABC
#
#          next_action  delivery_date  delivery_route account_manager
# 0  Follow-up with Cx            NaN             NaN          Johnny
# 1  Follow-up with Cx            NaN             NaN          Johnny
# 2  Follow-up with Cx            NaN             NaN          Johnny
# 3  Follow-up with Cx            NaN             NaN          Johnny
# 4  Follow-up with Cx            NaN             NaN          Johnny

# %%
for i in updated_orders['order_date']:
    print(i.day_name())
# Out:
# Saturday
# Tuesday
# Wednesday
# Thursday
# Friday
# Sunday
# Monday
# Thursday
# Sunday
# Monday
# Saturday
# Tuesday
# Wednesday
# Friday

# %%
updated_orders['weekday_name'] = updated_orders['order_date'].dt.day_name()

# %%
updated_orders.head()
# Out:
#   order_date  customer_id           name             email  product_id brand  \
# 0 2022-01-01         1001     John Adams    john@email.com          12   ABC
# 1 2022-01-04         1002    Jorden Haas  jorden@email.com          14   ABC
# 2 2022-01-05         1003  Pierce Glover  pierce@email.com          12   ABC
# 3 2022-01-06         1001     John Adams    john@email.com          14   ABC
# 4 2022-01-07         1002    Jorden Haas  jorden@email.com          14   ABC
#
#          next_action  delivery_date  delivery_route account_manager  \
# 0  Follow-up with Cx            NaN             NaN          Johnny
# 1  Follow-up with Cx            NaN             NaN          Johnny
# 2  Follow-up with Cx            NaN             NaN          Johnny
# 3  Follow-up with Cx            NaN             NaN          Johnny
# 4  Follow-up with Cx            NaN             NaN          Johnny
#
#   weekday_name
# 0     Saturday
# 1      Tuesday
# 2    Wednesday
# 3     Thursday
# 4       Friday

# %%
import datetime
from datetime import date

# %%
def delivery_date(weekday_name, order_date):
    if weekday_name == 'Thursday':
        return order_date + datetime.timedelta(days=4)
    elif weekday_name == 'Friday':
        return order_date + datetime.timedelta(days=4)
    elif weekday_name == 'Saturday':
        return order_date + datetime.timedelta(days=3)
    else:
        return order_date + datetime.timedelta(days=2)

# %%
updated_orders['delivery_date'] = updated_orders.apply(lambda x: delivery_date(x['weekday_name'], x['order_date']), axis=1)

# %%
def update_date(x):
    delivery_date(x['weekday_name'],x['order_date'])

# %%
updated_orders
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 1  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 2  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 3  2022-01-06         1001      John Adams    john@email.com          14
# 4  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 5  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 6  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 7  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 8  2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 9  2022-01-03         1001      John Adams    john@email.com          13
# 10 2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 11 2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 12 2022-01-12         1004  Carly Copeland               NaN          15
# 13 2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand        next_action delivery_date  delivery_route account_manager  \
# 0      ABC  Follow-up with Cx    2022-01-04             NaN          Johnny
# 1      ABC  Follow-up with Cx    2022-01-06             NaN          Johnny
# 2      ABC  Follow-up with Cx    2022-01-07             NaN          Johnny
# 3      ABC  Follow-up with Cx    2022-01-10             NaN          Johnny
# 4      ABC  Follow-up with Cx    2022-01-11             NaN          Johnny
# 5      ABC  Follow-up with Cx    2022-01-11             NaN          Johnny
# 6      ABC  Follow-up with Cx    2022-01-12             NaN          Johnny
# 7      ABC  Follow-up with Cx    2022-01-17             NaN          Johnny
# 8   Brand2       Ship Product    2022-01-04             NaN           Timmy
# 9   Brand2       Ship Product    2022-01-05             NaN           Timmy
# 10  Brand2       Ship Product    2022-01-11             NaN           Timmy
# 11  Brand2       Ship Product    2022-01-13             NaN           Timmy
# 12      DT       Ship Product    2022-01-14             NaN           Sammy
# 13      DT       Ship Product    2022-01-18             NaN           Sammy
#
#    weekday_name
# 0      Saturday
# 1       Tuesday
# 2     Wednesday
# 3      Thursday
# 4        Friday
# 5        Sunday
# 6        Monday
# 7      Thursday
# 8        Sunday
# 9        Monday
# 10     Saturday
# 11      Tuesday
# 12    Wednesday
# 13       Friday

# %%
updated_orders['day'] = updated_orders['order_date'].apply(lambda x: x.day)

# %%
updated_orders.head()
# Out:
#   order_date  customer_id           name             email  product_id brand  \
# 0 2022-01-01         1001     John Adams    john@email.com          12   ABC
# 1 2022-01-04         1002    Jorden Haas  jorden@email.com          14   ABC
# 2 2022-01-05         1003  Pierce Glover  pierce@email.com          12   ABC
# 3 2022-01-06         1001     John Adams    john@email.com          14   ABC
# 4 2022-01-07         1002    Jorden Haas  jorden@email.com          14   ABC
#
#          next_action delivery_date  delivery_route account_manager  \
# 0  Follow-up with Cx    2022-01-04             NaN          Johnny
# 1  Follow-up with Cx    2022-01-06             NaN          Johnny
# 2  Follow-up with Cx    2022-01-07             NaN          Johnny
# 3  Follow-up with Cx    2022-01-10             NaN          Johnny
# 4  Follow-up with Cx    2022-01-11             NaN          Johnny
#
#   weekday_name  day
# 0     Saturday    1
# 1      Tuesday    4
# 2    Wednesday    5
# 3     Thursday    6
# 4       Friday    7

# %%
# if we don't want to use lambda, we can also store a defined function and use apply() to apply to it to the data frame
def day(x):
    return x.day

# %%
updated_orders['day_2'] = updated_orders['order_date'].apply(day)

# %%
updated_orders.head()
# Out:
#   order_date  customer_id           name             email  product_id brand  \
# 0 2022-01-01         1001     John Adams    john@email.com          12   ABC
# 1 2022-01-04         1002    Jorden Haas  jorden@email.com          14   ABC
# 2 2022-01-05         1003  Pierce Glover  pierce@email.com          12   ABC
# 3 2022-01-06         1001     John Adams    john@email.com          14   ABC
# 4 2022-01-07         1002    Jorden Haas  jorden@email.com          14   ABC
#
#          next_action delivery_date  delivery_route account_manager  \
# 0  Follow-up with Cx    2022-01-04             NaN          Johnny
# 1  Follow-up with Cx    2022-01-06             NaN          Johnny
# 2  Follow-up with Cx    2022-01-07             NaN          Johnny
# 3  Follow-up with Cx    2022-01-10             NaN          Johnny
# 4  Follow-up with Cx    2022-01-11             NaN          Johnny
#
#   weekday_name  day  day_2
# 0     Saturday    1      1
# 1      Tuesday    4      4
# 2    Wednesday    5      5
# 3     Thursday    6      6
# 4       Friday    7      7

# %% [markdown]
# ### An example of unit tests

# %%
# unit testing
assert day(date(2022,1,13)) == 13

# %%
def day_2(x):
    return x.day + 1

# %%
day_2(date(2022,1,13))
# Out:
# 14

# %%
assert day_2(date(2022,1,13)) == 13
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 assert day_2(date(2022,1,13)) == 13
#
# AssertionError:

# %%
list1 = [12, 14, 15, 68, 3, 25] # sorted list [3, 12, 14, 15, 25, 68]

# %%
def find_median(lst):
    length = len(lst)
    index = (length - 1) // 2

    if (length % 2):
        return lst[index]
    else:
        return (lst[index] + lst[index + 1])/2.0

# %%
# unit test would tell me that the function is not working properly, I expect the output to be 14.5 but I have an assertation error
assert find_median(list1) == 14.5
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 assert find_median(list1) == 14.5
#
# AssertionError:

# %%
find_median(list1)
# Out:
# 41.5

# %%
# my function is missing a sort() argument, thus the output is wrong
def find_median(lst):
    lst.sort()
    length = len(lst)
    index = (length - 1) // 2

    if (length % 2):
        return lst[index]
    else:
        return (lst[index] + lst[index + 1])/2.0

# %%
assert find_median(list1) == 14.5 # now we fixed the function and we have a pass

# %% [markdown]
# ### Back to our dataframe

# %%
updated_orders.drop('day_2', axis=1, inplace=True)

# %%
updated_orders.head()
# Out:
#   order_date  customer_id           name             email  product_id brand  \
# 0 2022-01-01         1001     John Adams    john@email.com          12   ABC
# 1 2022-01-04         1002    Jorden Haas  jorden@email.com          14   ABC
# 2 2022-01-05         1003  Pierce Glover  pierce@email.com          12   ABC
# 3 2022-01-06         1001     John Adams    john@email.com          14   ABC
# 4 2022-01-07         1002    Jorden Haas  jorden@email.com          14   ABC
#
#          next_action delivery_date  delivery_route account_manager  \
# 0  Follow-up with Cx    2022-01-04             NaN          Johnny
# 1  Follow-up with Cx    2022-01-06             NaN          Johnny
# 2  Follow-up with Cx    2022-01-07             NaN          Johnny
# 3  Follow-up with Cx    2022-01-10             NaN          Johnny
# 4  Follow-up with Cx    2022-01-11             NaN          Johnny
#
#   weekday_name  day
# 0     Saturday    1
# 1      Tuesday    4
# 2    Wednesday    5
# 3     Thursday    6
# 4       Friday    7

# %%
def delivery_route(x):
    if x >= 1 and x <= 10:
        return "UPS"
    elif x>=11 and x<=20:
        return "Canada Post"
    else:
        return "FedEx"

# %%
updated_orders['delivery_route'] = updated_orders['day'].apply(delivery_route)

# %%
updated_orders
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 1  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 2  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 3  2022-01-06         1001      John Adams    john@email.com          14
# 4  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 5  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 6  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 7  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 8  2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 9  2022-01-03         1001      John Adams    john@email.com          13
# 10 2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 11 2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 12 2022-01-12         1004  Carly Copeland               NaN          15
# 13 2022-01-14         1004  Carly Copeland               NaN          15
#
#      brand        next_action delivery_date delivery_route account_manager  \
# 0      ABC  Follow-up with Cx    2022-01-04            UPS          Johnny
# 1      ABC  Follow-up with Cx    2022-01-06            UPS          Johnny
# 2      ABC  Follow-up with Cx    2022-01-07            UPS          Johnny
# 3      ABC  Follow-up with Cx    2022-01-10            UPS          Johnny
# 4      ABC  Follow-up with Cx    2022-01-11            UPS          Johnny
# 5      ABC  Follow-up with Cx    2022-01-11            UPS          Johnny
# 6      ABC  Follow-up with Cx    2022-01-12            UPS          Johnny
# 7      ABC  Follow-up with Cx    2022-01-17    Canada Post          Johnny
# 8   Brand2       Ship Product    2022-01-04            UPS           Timmy
# 9   Brand2       Ship Product    2022-01-05            UPS           Timmy
# 10  Brand2       Ship Product    2022-01-11            UPS           Timmy
# 11  Brand2       Ship Product    2022-01-13    Canada Post           Timmy
# 12      DT       Ship Product    2022-01-14    Canada Post           Sammy
# 13      DT       Ship Product    2022-01-18    Canada Post           Sammy
#
#    weekday_name  day
# 0      Saturday    1
# 1       Tuesday    4
# 2     Wednesday    5
# 3      Thursday    6
# 4        Friday    7
# 5        Sunday    9
# 6        Monday   10
# 7      Thursday   13
# 8        Sunday    2
# 9        Monday    3
# 10     Saturday    8
# 11      Tuesday   11
# 12    Wednesday   12
# 13       Friday   14

# %%
updated_orders['email'] = updated_orders['email'].fillna('Missing Email')

# %%
updated_orders
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 1  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 2  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 3  2022-01-06         1001      John Adams    john@email.com          14
# 4  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 5  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 6  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 7  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 8  2022-01-02         1002     Jorden Haas  jorden@email.com          13
# 9  2022-01-03         1001      John Adams    john@email.com          13
# 10 2022-01-08         1003   Pierce Glover  pierce@email.com          13
# 11 2022-01-11         1003   Pierce Glover  pierce@email.com          13
# 12 2022-01-12         1004  Carly Copeland     Missing Email          15
# 13 2022-01-14         1004  Carly Copeland     Missing Email          15
#
#      brand        next_action delivery_date delivery_route account_manager  \
# 0      ABC  Follow-up with Cx    2022-01-04            UPS          Johnny
# 1      ABC  Follow-up with Cx    2022-01-06            UPS          Johnny
# 2      ABC  Follow-up with Cx    2022-01-07            UPS          Johnny
# 3      ABC  Follow-up with Cx    2022-01-10            UPS          Johnny
# 4      ABC  Follow-up with Cx    2022-01-11            UPS          Johnny
# 5      ABC  Follow-up with Cx    2022-01-11            UPS          Johnny
# 6      ABC  Follow-up with Cx    2022-01-12            UPS          Johnny
# 7      ABC  Follow-up with Cx    2022-01-17    Canada Post          Johnny
# 8   Brand2       Ship Product    2022-01-04            UPS           Timmy
# 9   Brand2       Ship Product    2022-01-05            UPS           Timmy
# 10  Brand2       Ship Product    2022-01-11            UPS           Timmy
# 11  Brand2       Ship Product    2022-01-13    Canada Post           Timmy
# 12      DT       Ship Product    2022-01-14    Canada Post           Sammy
# 13      DT       Ship Product    2022-01-18    Canada Post           Sammy
#
#    weekday_name  day
# 0      Saturday    1
# 1       Tuesday    4
# 2     Wednesday    5
# 3      Thursday    6
# 4        Friday    7
# 5        Sunday    9
# 6        Monday   10
# 7      Thursday   13
# 8        Sunday    2
# 9        Monday    3
# 10     Saturday    8
# 11      Tuesday   11
# 12    Wednesday   12
# 13       Friday   14

# %%
# create 2 final lists: customers that we need to follow-up with, and customers to ship the product to
follow_up = updated_orders[(updated_orders['next_action'] == 'Follow-up with Cx') | (updated_orders['email'] == 'Missing Email')]

# %%
follow_up
# Out:
#    order_date  customer_id            name             email  product_id  \
# 0  2022-01-01         1001      John Adams    john@email.com          12
# 1  2022-01-04         1002     Jorden Haas  jorden@email.com          14
# 2  2022-01-05         1003   Pierce Glover  pierce@email.com          12
# 3  2022-01-06         1001      John Adams    john@email.com          14
# 4  2022-01-07         1002     Jorden Haas  jorden@email.com          14
# 5  2022-01-09         1004  Carly Copeland   carly@email.com          12
# 6  2022-01-10         1002     Jorden Haas  jorden@email.com          12
# 7  2022-01-13         1003   Pierce Glover  pierce@email.com          12
# 12 2022-01-12         1004  Carly Copeland     Missing Email          15
# 13 2022-01-14         1004  Carly Copeland     Missing Email          15
#
#    brand        next_action delivery_date delivery_route account_manager  \
# 0    ABC  Follow-up with Cx    2022-01-04            UPS          Johnny
# 1    ABC  Follow-up with Cx    2022-01-06            UPS          Johnny
# 2    ABC  Follow-up with Cx    2022-01-07            UPS          Johnny
# 3    ABC  Follow-up with Cx    2022-01-10            UPS          Johnny
# 4    ABC  Follow-up with Cx    2022-01-11            UPS          Johnny
# 5    ABC  Follow-up with Cx    2022-01-11            UPS          Johnny
# 6    ABC  Follow-up with Cx    2022-01-12            UPS          Johnny
# 7    ABC  Follow-up with Cx    2022-01-17    Canada Post          Johnny
# 12    DT       Ship Product    2022-01-14    Canada Post           Sammy
# 13    DT       Ship Product    2022-01-18    Canada Post           Sammy
#
#    weekday_name  day
# 0      Saturday    1
# 1       Tuesday    4
# 2     Wednesday    5
# 3      Thursday    6
# 4        Friday    7
# 5        Sunday    9
# 6        Monday   10
# 7      Thursday   13
# 12    Wednesday   12
# 13       Friday   14

# %%
ship = updated_orders[(updated_orders['next_action'] == 'Ship Product') & (updated_orders['email'] != 'Missing Email')]

# %%
# store to csv
ship.to_csv('/users/filepath/file.csv')
# Out:
#    order_date  customer_id           name             email  product_id  \
# 8  2022-01-02         1002    Jorden Haas  jorden@email.com          13
# 9  2022-01-03         1001     John Adams    john@email.com          13
# 10 2022-01-08         1003  Pierce Glover  pierce@email.com          13
# 11 2022-01-11         1003  Pierce Glover  pierce@email.com          13
#
#      brand   next_action delivery_date delivery_route account_manager  \
# 8   Brand2  Ship Product    2022-01-04            UPS           Timmy
# 9   Brand2  Ship Product    2022-01-05            UPS           Timmy
# 10  Brand2  Ship Product    2022-01-11            UPS           Timmy
# 11  Brand2  Ship Product    2022-01-13    Canada Post           Timmy
#
#    weekday_name  day
# 8        Sunday    2
# 9        Monday    3
# 10     Saturday    8
# 11      Tuesday   11
